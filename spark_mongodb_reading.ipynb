# %%
from pyspark.sql import SparkSession
import pandas as pd
from pyspark.sql.functions import *

# %%
sparksession=SparkSession.builder.appName("Mongodb_Read")\
.config("spark.mongodb.input.uri","mongodb+srv://admin:password@recomenditionengine.fjt2t.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")\
.config("spark.mongodb.output.uri","mongodb+srv://admin:password@recomenditionengine.fjt2t.mongodb.net/myFirstDatabase?retryWrites=true&w=majority").getOrCreate()

# %%
sparksession
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3474399086759128#setting/sparkui/0220-111515-pwhifhpj/driver-1259795780927418030">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data_mongo_user=sparksession.read.format("mongo").option("database","verimaratonu").option("collection","Als_User_Recomend").option("uri","mongodb+srv://admin:password@recomenditionengine.fjt2t.mongodb.net/myFirstDatabase?retryWrites=true&w=majority").load()

# %%
data_mongo_user.show(truncate=False)
# Out:
# +--------------------------+------------------------------------------------------------------------------------+------+
# |_id                       |recommendations                                                                     |userId|
# +--------------------------+------------------------------------------------------------------------------------+------+
# |{62122cd78bbe735ae386ef8f}|[{2361, 4.0375776290893555}, {3181, 3.888911247253418}, {3973, 3.6887171268463135}] |1     |
# |{62122cd78bbe735ae386ef90}|[{6413, 4.726029872894287}, {4056, 4.588133335113525}, {1192, 4.479974269866943}]   |2     |
# |{62122cd78bbe735ae386ef91}|[{67504, 4.804405689239502}, {83411, 4.804405689239502}, {83318, 4.804405689239502}]|3     |
# |{62122cd78bbe735ae386ef92}|[{67504, 6.563291072845459}, {83411, 6.563291072845459}, {83318, 6.563291072845459}]|4     |
# |{62122cd78bbe735ae386ef93}|[{8530, 4.977640628814697}, {83411, 4.876113414764404}, {67504, 4.876113414764404}] |5     |
# ...

# %%
data_mongo_item=sparksession.read.format("mongo").option("database","verimaratonu").option("collection","Als_Item_Recomend").option("uri","mongodb+srv://admin:password@recomenditionengine.fjt2t.mongodb.net/myFirstDatabase?retryWrites=true&w=majority").load()

# %%
data_mongo_item.show(truncate=False)
# Out:
# +--------------------------+-------+---------------------------------------------------------------------------------+
# |_id                       |movieId|recommendations                                                                  |
# +--------------------------+-------+---------------------------------------------------------------------------------+
# |{62122cf98bbe735ae386f440}|10     |[{46, 4.963094711303711}, {113, 4.8726396560668945}, {145, 4.784854888916016}]   |
# |{62122cf98bbe735ae386f441}|21     |[{517, 4.760989189147949}, {156, 4.726446151733398}, {37, 4.629570960998535}]    |
# |{62122cf98bbe735ae386f442}|24     |[{228, 4.818799018859863}, {113, 4.769654750823975}, {308, 4.656328201293945}]   |
# |{62122cf98bbe735ae386f443}|25     |[{154, 5.022727012634277}, {112, 4.908860683441162}, {637, 4.827247619628906}]   |
# |{62122cf98bbe735ae386f444}|29     |[{113, 5.176464557647705}, {401, 5.061172962188721}, {298, 4.99948263168335}]    |
# ...
